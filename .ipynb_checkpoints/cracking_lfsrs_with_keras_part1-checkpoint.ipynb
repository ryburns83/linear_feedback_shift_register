# %% [markdown]
# # $\textbf{Part 1. Predicting LFSR States Using Feedforward Neural Networks}$
# $\text{Author: Ryan Burns}$
#
# #### $\textbf{Linear Feedback Shift Registers (LFSRs)}$
# $\text{For background on LFSRs and maximum-length }m\text{-sequences, visit: }\textit{https://en.wikipedia.org/wiki/Linear-feedback_shift_register.}$
# $\text{It is assumed that a finite list of primitive polynomial coefficients (stored as hex values) are available for the polynomial degree specified below}$
# $\text{via a locally stored file with name <degree>.txt. For degree-10 polynomials, for example, the corresponding primitive polynomial coefficients}$
# $\text{would have file name 10.txt. LFSRs are built for each polynomial, each yielding a pseudorandom binary sequence of length/period }2^{\text{degree}}-1.$
#
# #### $\textbf{Prediction of LFSR State }n + 1\textbf{ Given State }n$
# $\text{Suppose we are given an arbitrary LFSR feedback polynomial and we build a representation of the LFSR in software. Using this LFSR, and}$
# $\text{assuming the feedback polynomial is primitive in a polynomial ring of fixed degree over }GF(2)\text{, we can generate a maximum-length binary}$
# $\text{sequence which has well-documented correlation properties which make them desirable building blocks for stream ciphers or spread-spectrum}$
# $\text{codes, to name a few examples. On their own, LFSRs do not afford any real cryptographic protection, being famously susceptible to correlation}$
# $\text{attacks. Speaking of attacks, our goal in this notebook is to demonstrate that we can use a }\textit{very}\text{ simple neural network to predict LFSR behavior.}$
# $\text{Specifically, we posit that a two-layer (i.e., single hidden-layer) feedforward neural network can readily predict the state-evolution of an arbitrary}$
# $\text{LFSR. For simplicity, we constrain this network to have a very specific architecture. Its input layer consists of a fixed-length binary vector that}$
# $\text{represents the LFSR state vector at some time index (epoch) }n\text{. We use the ground truth register state at index / epoch }n + 1\text{ to train a the network}$
# $\text{to develop a latent representation of the finite field recursion. Both layers of the network are sigmoid connections, representing soft approximations}$
# $\text{of boolean gates, outputing activations in the unit interval, }[0,1].\text{ These layers assume no bias terms, only weighted combinations of inputs. For}$
# $\text{an LFSR of recursion-order/polynomial degree }deg\text{, the first (and only) hidden layer consists a total of }2\times deg\text{ weighted sigmoidal activations.}$
# $\text{The output layer consists of the }deg\text{ total activations predicting }deg\text{ total bits in the LFSR state vector at epoch }n + 1\text{, for all }n\text{. These binary}$
# $\text{activations are trained against the true LFSR state vectors at these indices }n + 1\text{ using a binary cross-entropy error function. The population of}$
# $\text{observations are the }deg\text{-length LFSR states across all epochs in one full }m\text{-sequence period / cycle. The labels for the error function are the }$
# $deg\text{-length state vector values upon 1 iteration of the LFSR recursion, per observation.}$
#
# #### $\textbf{Part 1 of This Notebook}$
# $\text{Part 1 of this notebook prototypes a feedforward binary (bias-less) neural network using Keras, training it as described above using RMSprop. The}$
# $\text{model is given too few degrees of freedom to completely memorize the bits, so it must learn a latent representation of the underlying finite field}$
# $\text{mathematics defining the recurrence relation. After sufficiently many training epochs, the model has been tested to converge to 100}\%\text{ accuracy}$
# $\text{for all degree-10 primitive polynomials in the file 10.txt. Primitive polynomials defining }m\text{-sequences for other polynomial degrees are available}$
# $\text{for download at the following site: }\textit{https://users.ece.cmu.edu/~koopman/lfsr/index.html}\text{. Future efforts may build this proof-of-concept out to}$
# $\text{higher degree recursions and more complicated kinds of stream ciphers. For now, we demonstrate that a relatively shallow binary network is}$
# $\text{sufficiently powerful to "crack" (i.e., predict) an LFSR's underlying recursive state vector mapping.}$
#
# $\text{In addition to training the network, we animate the results in a plot which depicts the time-evolution of the LFSR recursion and the neural}$
# $\text{network's state predictions. In addition, options are provided for plotting the correlation properties of the }m\text{-sequence training data and the Keras}$
# $\text{model metrics vs training epoch, respectively. Documentation and source code for all the functions below can be found in this repo's modules.}$

# %% [markdown]
# ### $\textbf{Import Dependencies}$

# %%
# System imports
from os import environ
from time import time

# So numpy and Tensorflow can cooperate
environ['KMP_DUPLICATE_LIB_OK']='True'

# Numpy imports
from numpy import array, matmul, transpose, identity, hstack, vstack, shape
from numpy import expand_dims, zeros, correlate, linspace, arange, max

# Galois / LFSR utilities
from galois_tools import *
from m_sequence_viz import *
from lfsr_network_viz import *
from ml_utils import *

# Plotting functionality
from matplotlib import pyplot as plt
from matplotlib.animation import FuncAnimation

# Tensorflow/Keras functionality
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model;
from tensorflow.keras.optimizers import RMSprop;
from tensorflow.keras.metrics import TruePositives, FalsePositives, TrueNegatives, FalseNegatives;

# %% [markdown]
# ### $\textbf{Plotting Macro (Requires IPython)}$

# %%
# %matplotlib notebook

# %% [markdown]
# ### $\textbf{Specify LFSR & Neural Net Parameters}$

# %%
###########################
# Specify LFSR parameters #
###########################

# Primitive polynomial degree
deg = 10 # (= number of bits)

# Length of m-sequence generated
M = 2**deg - 1 # (bits)

# Initial state of register
seed = 1 # (decimal form)

# Primitive polynomial choice
p = 16 # (index in catalog)

###############################
# Network training parameters #
###############################

# Number of RMSprop training epochs
N_epoch = 16000

# Batch size equal to m-sequence length
N_batch = 2**deg - 1

# Learning rate for RMSprop
learning_rate = 0.001

#########################
# Behavioral parameters #
#########################

# Turn ON/OFF correlation plot
plot_correlations = True

# Turn ON/OFF true vs. predicted mask plot
plot_prediction_masks = True

# %% [markdown]
# ### $\textbf{Load Primitive Polynomial Coefficients of Specified Degree Over }GF(2)$

# %%
#############################################################
# Load coeff. of primitive polynomials over GF(2) from file #
#############################################################

# Read list of primitive polynomial coefficients for definition
# of the linear feedback shift registers yielding m-sequences
coeff_catalog = read_polynomials_from_file(deg=deg,
    path='./primitive_polynomials/')

###########################################################
# Generate linear feedback shift registers w/ polynomials #
###########################################################

# Define a bank of LFSRs - 1 per polynomial in the catalog
LFSRs = [LFSR(mask=eval(hex2bin(coeff_catalog[n], nbits=deg)), 
    seed=seed, order=deg, register_id=str(n)) 
    for n in range(len(coeff_catalog))]

# %% [markdown]
# ### $\textbf{Visualize Auto- & Cross-Correlations of Two m-Sequences}$

# %%
# Optional correlation plot...
if plot_correlations:

    ##################################################
    # Generate m-sequences for each LFSR in the bank #
    ##################################################

    # Maximimum length binary sequences of length M = 2^deg - 1 via LFSRs
    m_sequences = vstack(tuple(register.m_sequence() for register in LFSRs))

    # Convert m-sequences from logical {0,1} to algebraic {-1,+1} representation
    algebraic_m_sequences = m_sequences.astype('float64') * 2 - 1

    ###################################################
    # Visualize correlation properties of m-sequences #
    ###################################################

    # Plot the correlations of the 1st 2 m-sequences generated above
    correlation_example(m_sequence0=algebraic_m_sequences[p,:], 
        m_sequence1=algebraic_m_sequences[p + 1,:],  deg=deg)
# Out:
# <div id='c69a1443-6e54-40f8-b5ad-40aace6d48c5'></div>

# %% [markdown]
# ### $\textbf{Form Observations of }n^{\text{th}}\textbf{ LFSR State for Prediction of }(n + 1)^\text{st}\textbf{ State, for }n=0,1,2,\ldots$

# %%
#########################################################
# Buffer in b[n] a total of 2^deg + deg m-sequence bits #
#########################################################

# Maximimum length binary sequences of length M = 2^deg - 1 via LFSRs
b = vstack(tuple(register.stream(2**deg + deg) for register in LFSRs))

########################################################
# n'th LFSR register state observations, n = 0,1,2,... #
########################################################

# Input LFSR windows (deg-bit observation vectors)
X = array([b[p,n:(n + deg)] for n in range(b.shape[1] - deg - 1)])

############################################################
# (n+1)'st LFSR register state observations, n = 0,1,2,... #
############################################################

# Target LFSR windows, 1 epoch into future from X
Y = array([b[p,(n + 1):(1 + n + deg)] for n in range(b.shape[1] - deg - 1)])

# %% [markdown]
# ### $\textbf{Define Feedforward Binary Neural Network}$

# %%
# Use Keras to define feedforward binary neural network, with
# two sigmoidal layers (without bias terms) for estimation of
# the LFSR state vector at epoch n + 1 from the state at epoch n
model = feedforward_lfsr_predictor(deg=deg, 
    learning_rate=learning_rate, print_summary=True)
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 10)]              0
# _________________________________________________________________
# hidden (Dense)               (None, 20)                200
# _________________________________________________________________
# output (Dense)               (None, 10)                200
# =================================================================
# Total params: 400
# Trainable params: 400
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### $\textbf{Fit Sigmoid Model to Predict Register State }n + 1\textbf{ from State }n$

# %%
# Model training
model.fit(
    
    # Input dataset
    x=X, # state vectot "observation" bits
    y=Y, # future-state predicted bits
    
    # Batch size
    batch_size=N_batch,
    
    # Number of training epochs
    epochs=N_epoch,
    
    # Print progress
    verbose=1,
    
    # Set aside fraction for validation
    validation_split=0, # (use everything)
    
    # False for time series
    shuffle=False,
    
    # Parallelize job across 2 workers
    workers=1,
    use_multiprocessing=False);
# Out:
# Train on 1023 samples
# Epoch 1/16000
# 1023/1023 [==============================] - 1s 1ms/sample - loss: 0.7457 - true_positives: 2130.0000 - true_negatives: 3048.0000 - false_positives: 2062.0000 - false_negatives: 2990.0000
# Epoch 2/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.7407 - true_positives: 2170.0000 - true_negatives: 3024.0000 - false_positives: 2086.0000 - false_negatives: 2950.0000
# Epoch 3/16000
# 1023/1023 [==============================] - 0s 5us/sample - loss: 0.7373 - true_positives: 2198.0000 - true_negatives: 3011.0000 - false_positives: 2099.0000 - false_negatives: 2922.0000
# Epoch 4/16000
# 1023/1023 [==============================] - 0s 5us/sample - loss: 0.7346 - true_positives: 2223.0000 - true_negatives: 3004.0000 - false_positives: 2106.0000 - false_negatives: 2897.0000
# Epoch 5/16000
# 1023/1023 [==============================] - 0s 5us/sample - loss: 0.7323 - true_positives: 2248.0000 - true_negatives: 2997.0000 - false_positives: 2113.0000 - false_negatives: 2872.0000
# Epoch 6/16000
# 1023/1023 [==============================] - 0s 5us/sample - loss: 0.7303 - true_positives: 2279.0000 - true_negatives: 2989.0000 - false_positives: 2121.0000 - false_negatives: 2841.0000
# Epoch 7/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.7285 - true_positives: 2301.0000 - true_negatives: 2984.0000 - false_positives: 2126.0000 - false_negatives: 2819.0000
# Epoch 8/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.7267 - true_positives: 2330.0000 - true_negatives: 2974.0000 - false_positives: 2136.0000 - false_negatives: 2790.0000
# Epoch 9/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.7251 - true_positives: 2361.0000 - true_negatives: 2972.0000 - false_positives: 2138.0000 - false_negatives: 2759.0000
# Epoch 10/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.7236 - true_positives: 2382.0000 - true_negatives: 2966.0000 - false_positives: 2144.0000 - false_negatives: 2738.0000
# Epoch 11/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.7222 - true_positives: 2403.0000 - true_negatives: 2970.0000 - false_positives: 2140.0000 - false_negatives: 2717.0000
# Epoch 12/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.7208 - true_positives: 2434.0000 - true_negatives: 2973.0000 - false_positives: 2137.0000 - false_negatives: 2686.0000
# Epoch 13/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.7195 - true_positives: 2465.0000 - true_negatives: 2968.0000 - false_positives: 2142.0000 - false_negatives: 2655.0000
# Epoch 14/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.7183 - true_positives: 2494.0000 - true_negatives: 2966.0000 - false_positives: 2144.0000 - false_negatives: 2626.0000
# Epoch 15/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.7171 - true_positives: 2525.0000 - true_negatives: 2969.0000 - false_positives: 2141.0000 - false_negatives: 2595.0000
# Epoch 16/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.7159 - true_positives: 2546.0000 - true_negatives: 2974.0000 - false_positives: 2136.0000 - false_negatives: 2574.0000
# Epoch 17/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.7147 - true_positives: 2568.0000 - true_negatives: 2975.0000 - false_positives: 2135.0000 - false_negatives: 2552.0000
# Epoch 18/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.7136 - true_positives: 2591.0000 - true_negatives: 2976.0000 - false_positives: 2134.0000 - false_negatives: 2529.0000
# Epoch 19/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.7125 - true_positives: 2618.0000 - true_negatives: 2984.0000 - false_positives: 2126.0000 - false_negatives: 2502.0000
# Epoch 20/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.7115 - true_positives: 2646.0000 - true_negatives: 2982.0000 - false_positives: 2128.0000 - false_negatives: 2474.0000
# Epoch 21/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.7105 - true_positives: 2672.0000 - true_negatives: 2984.0000 - false_positives: 2126.0000 - false_negatives: 2448.0000
# Epoch 22/16000
# 1023/1023 [==============================] - 0s 5us/sample - loss: 0.7095 - true_positives: 2705.0000 - true_negatives: 2992.0000 - false_positives: 2118.0000 - false_negatives: 2415.0000
# Epoch 23/16000
# 1023/1023 [==============================] - 0s 5us/sample - loss: 0.7085 - true_positives: 2728.0000 - true_negatives: 2994.0000 - false_positives: 2116.0000 - false_negatives: 2392.0000
# Epoch 24/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.7075 - true_positives: 2752.0000 - true_negatives: 2997.0000 - false_positives: 2113.0000 - false_negatives: 2368.0000
# Epoch 25/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.7066 - true_positives: 2781.0000 - true_negatives: 2999.0000 - false_positives: 2111.0000 - false_negatives: 2339.0000
# Epoch 26/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.7056 - true_positives: 2812.0000 - true_negatives: 2997.0000 - false_positives: 2113.0000 - false_negatives: 2308.0000
# Epoch 27/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.7047 - true_positives: 2823.0000 - true_negatives: 3004.0000 - false_positives: 2106.0000 - false_negatives: 2297.0000
# Epoch 28/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.7038 - true_positives: 2848.0000 - true_negatives: 3007.0000 - false_positives: 2103.0000 - false_negatives: 2272.0000
# Epoch 29/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.7029 - true_positives: 2872.0000 - true_negatives: 3011.0000 - false_positives: 2099.0000 - false_negatives: 2248.0000
# Epoch 30/16000
# 1023/1023 [==============================] - 0s 5us/sample - loss: 0.7021 - true_positives: 2899.0000 - true_negatives: 3005.0000 - false_positives: 2105.0000 - false_negatives: 2221.0000
# Epoch 31/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.7012 - true_positives: 2928.0000 - true_negatives: 3009.0000 - false_positives: 2101.0000 - false_negatives: 2192.0000
# Epoch 32/16000
# 1023/1023 [==============================] - 0s 5us/sample - loss: 0.7004 - true_positives: 2949.0000 - true_negatives: 3002.0000 - false_positives: 2108.0000 - false_negatives: 2171.0000
# Epoch 33/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6995 - true_positives: 2978.0000 - true_negatives: 3000.0000 - false_positives: 2110.0000 - false_negatives: 2142.0000
# Epoch 34/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6987 - true_positives: 2998.0000 - true_negatives: 3006.0000 - false_positives: 2104.0000 - false_negatives: 2122.0000
# Epoch 35/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6979 - true_positives: 3037.0000 - true_negatives: 2998.0000 - false_positives: 2112.0000 - false_negatives: 2083.0000
# Epoch 36/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6971 - true_positives: 3064.0000 - true_negatives: 2989.0000 - false_positives: 2121.0000 - false_negatives: 2056.0000
# Epoch 37/16000
# 1023/1023 [==============================] - 0s 5us/sample - loss: 0.6963 - true_positives: 3096.0000 - true_negatives: 2985.0000 - false_positives: 2125.0000 - false_negatives: 2024.0000
# Epoch 38/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6955 - true_positives: 3123.0000 - true_negatives: 2985.0000 - false_positives: 2125.0000 - false_negatives: 1997.0000
# Epoch 39/16000
# 1023/1023 [==============================] - 0s 5us/sample - loss: 0.6948 - true_positives: 3154.0000 - true_negatives: 2988.0000 - false_positives: 2122.0000 - false_negatives: 1966.0000
# Epoch 40/16000
# 1023/1023 [==============================] - 0s 5us/sample - loss: 0.6940 - true_positives: 3178.0000 - true_negatives: 2976.0000 - false_positives: 2134.0000 - false_negatives: 1942.0000
# Epoch 41/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6933 - true_positives: 3199.0000 - true_negatives: 2961.0000 - false_positives: 2149.0000 - false_negatives: 1921.0000
# Epoch 42/16000
# 1023/1023 [==============================] - 0s 5us/sample - loss: 0.6925 - true_positives: 3223.0000 - true_negatives: 2959.0000 - false_positives: 2151.0000 - false_negatives: 1897.0000
# Epoch 43/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6918 - true_positives: 3253.0000 - true_negatives: 2959.0000 - false_positives: 2151.0000 - false_negatives: 1867.0000
# Epoch 44/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6910 - true_positives: 3288.0000 - true_negatives: 2957.0000 - false_positives: 2153.0000 - false_negatives: 1832.0000
# Epoch 45/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6903 - true_positives: 3316.0000 - true_negatives: 2953.0000 - false_positives: 2157.0000 - false_negatives: 1804.0000
# Epoch 46/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6896 - true_positives: 3338.0000 - true_negatives: 2946.0000 - false_positives: 2164.0000 - false_negatives: 1782.0000
# Epoch 47/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6889 - true_positives: 3376.0000 - true_negatives: 2940.0000 - false_positives: 2170.0000 - false_negatives: 1744.0000
# Epoch 48/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6882 - true_positives: 3392.0000 - true_negatives: 2936.0000 - false_positives: 2174.0000 - false_negatives: 1728.0000
# Epoch 49/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6875 - true_positives: 3420.0000 - true_negatives: 2931.0000 - false_positives: 2179.0000 - false_negatives: 1700.0000
# Epoch 50/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6868 - true_positives: 3443.0000 - true_negatives: 2928.0000 - false_positives: 2182.0000 - false_negatives: 1677.0000
# Epoch 51/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6861 - true_positives: 3477.0000 - true_negatives: 2924.0000 - false_positives: 2186.0000 - false_negatives: 1643.0000
# Epoch 52/16000
# 1023/1023 [==============================] - 0s 5us/sample - loss: 0.6854 - true_positives: 3507.0000 - true_negatives: 2916.0000 - false_positives: 2194.0000 - false_negatives: 1613.0000
# Epoch 53/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6847 - true_positives: 3535.0000 - true_negatives: 2912.0000 - false_positives: 2198.0000 - false_negatives: 1585.0000
# Epoch 54/16000
# 1023/1023 [==============================] - 0s 5us/sample - loss: 0.6841 - true_positives: 3573.0000 - true_negatives: 2909.0000 - false_positives: 2201.0000 - false_negatives: 1547.0000
# Epoch 55/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6834 - true_positives: 3591.0000 - true_negatives: 2905.0000 - false_positives: 2205.0000 - false_negatives: 1529.0000
# Epoch 56/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6827 - true_positives: 3625.0000 - true_negatives: 2900.0000 - false_positives: 2210.0000 - false_negatives: 1495.0000
# Epoch 57/16000
# 1023/1023 [==============================] - 0s 5us/sample - loss: 0.6821 - true_positives: 3650.0000 - true_negatives: 2896.0000 - false_positives: 2214.0000 - false_negatives: 1470.0000
# Epoch 58/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6814 - true_positives: 3674.0000 - true_negatives: 2889.0000 - false_positives: 2221.0000 - false_negatives: 1446.0000
# Epoch 59/16000
# 1023/1023 [==============================] - 0s 5us/sample - loss: 0.6808 - true_positives: 3696.0000 - true_negatives: 2896.0000 - false_positives: 2214.0000 - false_negatives: 1424.0000
# Epoch 60/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6802 - true_positives: 3724.0000 - true_negatives: 2898.0000 - false_positives: 2212.0000 - false_negatives: 1396.0000
# Epoch 61/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6795 - true_positives: 3748.0000 - true_negatives: 2895.0000 - false_positives: 2215.0000 - false_negatives: 1372.0000
# Epoch 62/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6789 - true_positives: 3771.0000 - true_negatives: 2897.0000 - false_positives: 2213.0000 - false_negatives: 1349.0000
# Epoch 63/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6783 - true_positives: 3801.0000 - true_negatives: 2901.0000 - false_positives: 2209.0000 - false_negatives: 1319.0000
# Epoch 64/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6777 - true_positives: 3823.0000 - true_negatives: 2890.0000 - false_positives: 2220.0000 - false_negatives: 1297.0000
# Epoch 65/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6770 - true_positives: 3851.0000 - true_negatives: 2890.0000 - false_positives: 2220.0000 - false_negatives: 1269.0000
# Epoch 66/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6764 - true_positives: 3871.0000 - true_negatives: 2887.0000 - false_positives: 2223.0000 - false_negatives: 1249.0000
# Epoch 67/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6758 - true_positives: 3894.0000 - true_negatives: 2883.0000 - false_positives: 2227.0000 - false_negatives: 1226.0000
# Epoch 68/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6752 - true_positives: 3915.0000 - true_negatives: 2881.0000 - false_positives: 2229.0000 - false_negatives: 1205.0000
# Epoch 69/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6746 - true_positives: 3932.0000 - true_negatives: 2888.0000 - false_positives: 2222.0000 - false_negatives: 1188.0000
# Epoch 70/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6740 - true_positives: 3952.0000 - true_negatives: 2886.0000 - false_positives: 2224.0000 - false_negatives: 1168.0000
# Epoch 71/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6735 - true_positives: 3982.0000 - true_negatives: 2889.0000 - false_positives: 2221.0000 - false_negatives: 1138.0000
# Epoch 72/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6729 - true_positives: 4000.0000 - true_negatives: 2891.0000 - false_positives: 2219.0000 - false_negatives: 1120.0000
# Epoch 73/16000
# 1023/1023 [==============================] - 0s 9us/sample - loss: 0.6723 - true_positives: 4023.0000 - true_negatives: 2893.0000 - false_positives: 2217.0000 - false_negatives: 1097.0000
# Epoch 74/16000
# 1023/1023 [==============================] - 0s 9us/sample - loss: 0.6717 - true_positives: 4042.0000 - true_negatives: 2899.0000 - false_positives: 2211.0000 - false_negatives: 1078.0000
# Epoch 75/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6711 - true_positives: 4065.0000 - true_negatives: 2903.0000 - false_positives: 2207.0000 - false_negatives: 1055.0000
# Epoch 76/16000
# 1023/1023 [==============================] - 0s 8us/sample - loss: 0.6706 - true_positives: 4077.0000 - true_negatives: 2900.0000 - false_positives: 2210.0000 - false_negatives: 1043.0000
# Epoch 77/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6700 - true_positives: 4102.0000 - true_negatives: 2908.0000 - false_positives: 2202.0000 - false_negatives: 1018.0000
# Epoch 78/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6695 - true_positives: 4120.0000 - true_negatives: 2909.0000 - false_positives: 2201.0000 - false_negatives: 1000.0000
# Epoch 79/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6689 - true_positives: 4141.0000 - true_negatives: 2911.0000 - false_positives: 2199.0000 - false_negatives: 979.0000
# Epoch 80/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6684 - true_positives: 4159.0000 - true_negatives: 2916.0000 - false_positives: 2194.0000 - false_negatives: 961.0000
# Epoch 81/16000
# 1023/1023 [==============================] - 0s 8us/sample - loss: 0.6678 - true_positives: 4175.0000 - true_negatives: 2920.0000 - false_positives: 2190.0000 - false_negatives: 945.0000
# Epoch 82/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6673 - true_positives: 4188.0000 - true_negatives: 2924.0000 - false_positives: 2186.0000 - false_negatives: 932.0000
# Epoch 83/16000
# 1023/1023 [==============================] - 0s 8us/sample - loss: 0.6667 - true_positives: 4207.0000 - true_negatives: 2929.0000 - false_positives: 2181.0000 - false_negatives: 913.0000
# Epoch 84/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6662 - true_positives: 4221.0000 - true_negatives: 2935.0000 - false_positives: 2175.0000 - false_negatives: 899.0000
# Epoch 85/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6657 - true_positives: 4240.0000 - true_negatives: 2935.0000 - false_positives: 2175.0000 - false_negatives: 880.0000
# Epoch 86/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6651 - true_positives: 4254.0000 - true_negatives: 2935.0000 - false_positives: 2175.0000 - false_negatives: 866.0000
# Epoch 87/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6646 - true_positives: 4265.0000 - true_negatives: 2943.0000 - false_positives: 2167.0000 - false_negatives: 855.0000
# Epoch 88/16000
# 1023/1023 [==============================] - 0s 8us/sample - loss: 0.6641 - true_positives: 4285.0000 - true_negatives: 2947.0000 - false_positives: 2163.0000 - false_negatives: 835.0000
# Epoch 89/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6636 - true_positives: 4299.0000 - true_negatives: 2952.0000 - false_positives: 2158.0000 - false_negatives: 821.0000
# Epoch 90/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6631 - true_positives: 4309.0000 - true_negatives: 2956.0000 - false_positives: 2154.0000 - false_negatives: 811.0000
# Epoch 91/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6626 - true_positives: 4323.0000 - true_negatives: 2961.0000 - false_positives: 2149.0000 - false_negatives: 797.0000
# Epoch 92/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6621 - true_positives: 4338.0000 - true_negatives: 2964.0000 - false_positives: 2146.0000 - false_negatives: 782.0000
# Epoch 93/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6616 - true_positives: 4357.0000 - true_negatives: 2966.0000 - false_positives: 2144.0000 - false_negatives: 763.0000
# Epoch 94/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6611 - true_positives: 4366.0000 - true_negatives: 2972.0000 - false_positives: 2138.0000 - false_negatives: 754.0000
# Epoch 95/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6606 - true_positives: 4373.0000 - true_negatives: 2976.0000 - false_positives: 2134.0000 - false_negatives: 747.0000
# Epoch 96/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6601 - true_positives: 4387.0000 - true_negatives: 2982.0000 - false_positives: 2128.0000 - false_negatives: 733.0000
# Epoch 97/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6596 - true_positives: 4399.0000 - true_negatives: 2987.0000 - false_positives: 2123.0000 - false_negatives: 721.0000
# Epoch 98/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6591 - true_positives: 4406.0000 - true_negatives: 2994.0000 - false_positives: 2116.0000 - false_negatives: 714.0000
# Epoch 99/16000
# 1023/1023 [==============================] - 0s 8us/sample - loss: 0.6586 - true_positives: 4416.0000 - true_negatives: 2999.0000 - false_positives: 2111.0000 - false_negatives: 704.0000
# Epoch 100/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6581 - true_positives: 4429.0000 - true_negatives: 3004.0000 - false_positives: 2106.0000 - false_negatives: 691.0000
# Epoch 101/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6577 - true_positives: 4433.0000 - true_negatives: 3011.0000 - false_positives: 2099.0000 - false_negatives: 687.0000
# Epoch 102/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6572 - true_positives: 4446.0000 - true_negatives: 3020.0000 - false_positives: 2090.0000 - false_negatives: 674.0000
# Epoch 103/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6567 - true_positives: 4463.0000 - true_negatives: 3029.0000 - false_positives: 2081.0000 - false_negatives: 657.0000
# Epoch 104/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6562 - true_positives: 4464.0000 - true_negatives: 3040.0000 - false_positives: 2070.0000 - false_negatives: 656.0000
# Epoch 105/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6558 - true_positives: 4473.0000 - true_negatives: 3056.0000 - false_positives: 2054.0000 - false_negatives: 647.0000
# Epoch 106/16000
# 1023/1023 [==============================] - 0s 5us/sample - loss: 0.6553 - true_positives: 4474.0000 - true_negatives: 3064.0000 - false_positives: 2046.0000 - false_negatives: 646.0000
# Epoch 107/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6548 - true_positives: 4482.0000 - true_negatives: 3076.0000 - false_positives: 2034.0000 - false_negatives: 638.0000
# Epoch 108/16000
# 1023/1023 [==============================] - 0s 5us/sample - loss: 0.6544 - true_positives: 4485.0000 - true_negatives: 3092.0000 - false_positives: 2018.0000 - false_negatives: 635.0000
# Epoch 109/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6539 - true_positives: 4487.0000 - true_negatives: 3112.0000 - false_positives: 1998.0000 - false_negatives: 633.0000
# Epoch 110/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6534 - true_positives: 4485.0000 - true_negatives: 3129.0000 - false_positives: 1981.0000 - false_negatives: 635.0000
# Epoch 111/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6530 - true_positives: 4487.0000 - true_negatives: 3148.0000 - false_positives: 1962.0000 - false_negatives: 633.0000
# Epoch 112/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6525 - true_positives: 4481.0000 - true_negatives: 3169.0000 - false_positives: 1941.0000 - false_negatives: 639.0000
# Epoch 113/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6521 - true_positives: 4482.0000 - true_negatives: 3188.0000 - false_positives: 1922.0000 - false_negatives: 638.0000
# Epoch 114/16000
# 1023/1023 [==============================] - 0s 5us/sample - loss: 0.6516 - true_positives: 4483.0000 - true_negatives: 3201.0000 - false_positives: 1909.0000 - false_negatives: 637.0000
# Epoch 115/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6512 - true_positives: 4476.0000 - true_negatives: 3218.0000 - false_positives: 1892.0000 - false_negatives: 644.0000
# Epoch 116/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6507 - true_positives: 4463.0000 - true_negatives: 3232.0000 - false_positives: 1878.0000 - false_negatives: 657.0000
# Epoch 117/16000
# 1023/1023 [==============================] - 0s 5us/sample - loss: 0.6503 - true_positives: 4452.0000 - true_negatives: 3250.0000 - false_positives: 1860.0000 - false_negatives: 668.0000
# Epoch 118/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6498 - true_positives: 4449.0000 - true_negatives: 3265.0000 - false_positives: 1845.0000 - false_negatives: 671.0000
# Epoch 119/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6494 - true_positives: 4443.0000 - true_negatives: 3284.0000 - false_positives: 1826.0000 - false_negatives: 677.0000
# Epoch 120/16000
# 1023/1023 [==============================] - 0s 5us/sample - loss: 0.6489 - true_positives: 4438.0000 - true_negatives: 3308.0000 - false_positives: 1802.0000 - false_negatives: 682.0000
# Epoch 121/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6485 - true_positives: 4432.0000 - true_negatives: 3319.0000 - false_positives: 1791.0000 - false_negatives: 688.0000
# Epoch 122/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6480 - true_positives: 4428.0000 - true_negatives: 3339.0000 - false_positives: 1771.0000 - false_negatives: 692.0000
# Epoch 123/16000
# 1023/1023 [==============================] - 0s 5us/sample - loss: 0.6476 - true_positives: 4422.0000 - true_negatives: 3358.0000 - false_positives: 1752.0000 - false_negatives: 698.0000
# Epoch 124/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6471 - true_positives: 4419.0000 - true_negatives: 3372.0000 - false_positives: 1738.0000 - false_negatives: 701.0000
# Epoch 125/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6467 - true_positives: 4415.0000 - true_negatives: 3387.0000 - false_positives: 1723.0000 - false_negatives: 705.0000
# Epoch 126/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6462 - true_positives: 4412.0000 - true_negatives: 3402.0000 - false_positives: 1708.0000 - false_negatives: 708.0000
# Epoch 127/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6458 - true_positives: 4412.0000 - true_negatives: 3423.0000 - false_positives: 1687.0000 - false_negatives: 708.0000
# Epoch 128/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6453 - true_positives: 4406.0000 - true_negatives: 3443.0000 - false_positives: 1667.0000 - false_negatives: 714.0000
# Epoch 129/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6449 - true_positives: 4403.0000 - true_negatives: 3457.0000 - false_positives: 1653.0000 - false_negatives: 717.0000
# Epoch 130/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6444 - true_positives: 4401.0000 - true_negatives: 3474.0000 - false_positives: 1636.0000 - false_negatives: 719.0000
# Epoch 131/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6440 - true_positives: 4404.0000 - true_negatives: 3495.0000 - false_positives: 1615.0000 - false_negatives: 716.0000
# Epoch 132/16000
# 1023/1023 [==============================] - 0s 8us/sample - loss: 0.6435 - true_positives: 4405.0000 - true_negatives: 3510.0000 - false_positives: 1600.0000 - false_negatives: 715.0000
# Epoch 133/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6431 - true_positives: 4403.0000 - true_negatives: 3529.0000 - false_positives: 1581.0000 - false_negatives: 717.0000
# Epoch 134/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6426 - true_positives: 4407.0000 - true_negatives: 3541.0000 - false_positives: 1569.0000 - false_negatives: 713.0000
# Epoch 135/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6422 - true_positives: 4407.0000 - true_negatives: 3548.0000 - false_positives: 1562.0000 - false_negatives: 713.0000
# Epoch 136/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6417 - true_positives: 4409.0000 - true_negatives: 3563.0000 - false_positives: 1547.0000 - false_negatives: 711.0000
# Epoch 137/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6413 - true_positives: 4412.0000 - true_negatives: 3576.0000 - false_positives: 1534.0000 - false_negatives: 708.0000
# Epoch 138/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6408 - true_positives: 4411.0000 - true_negatives: 3586.0000 - false_positives: 1524.0000 - false_negatives: 709.0000
# Epoch 139/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6404 - true_positives: 4414.0000 - true_negatives: 3594.0000 - false_positives: 1516.0000 - false_negatives: 706.0000
# Epoch 140/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6399 - true_positives: 4415.0000 - true_negatives: 3608.0000 - false_positives: 1502.0000 - false_negatives: 705.0000
# Epoch 141/16000
# 1023/1023 [==============================] - 0s 5us/sample - loss: 0.6395 - true_positives: 4416.0000 - true_negatives: 3619.0000 - false_positives: 1491.0000 - false_negatives: 704.0000
# Epoch 142/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6390 - true_positives: 4415.0000 - true_negatives: 3621.0000 - false_positives: 1489.0000 - false_negatives: 705.0000
# Epoch 143/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6386 - true_positives: 4416.0000 - true_negatives: 3630.0000 - false_positives: 1480.0000 - false_negatives: 704.0000
# Epoch 144/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6381 - true_positives: 4416.0000 - true_negatives: 3634.0000 - false_positives: 1476.0000 - false_negatives: 704.0000
# Epoch 145/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6377 - true_positives: 4418.0000 - true_negatives: 3650.0000 - false_positives: 1460.0000 - false_negatives: 702.0000
# Epoch 146/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6372 - true_positives: 4421.0000 - true_negatives: 3658.0000 - false_positives: 1452.0000 - false_negatives: 699.0000
# Epoch 147/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6367 - true_positives: 4423.0000 - true_negatives: 3666.0000 - false_positives: 1444.0000 - false_negatives: 697.0000
# Epoch 148/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6363 - true_positives: 4426.0000 - true_negatives: 3671.0000 - false_positives: 1439.0000 - false_negatives: 694.0000
# Epoch 149/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6358 - true_positives: 4427.0000 - true_negatives: 3681.0000 - false_positives: 1429.0000 - false_negatives: 693.0000
# Epoch 150/16000
# 1023/1023 [==============================] - 0s 5us/sample - loss: 0.6354 - true_positives: 4429.0000 - true_negatives: 3690.0000 - false_positives: 1420.0000 - false_negatives: 691.0000
# Epoch 151/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6349 - true_positives: 4434.0000 - true_negatives: 3692.0000 - false_positives: 1418.0000 - false_negatives: 686.0000
# Epoch 152/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6345 - true_positives: 4440.0000 - true_negatives: 3702.0000 - false_positives: 1408.0000 - false_negatives: 680.0000
# Epoch 153/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6340 - true_positives: 4443.0000 - true_negatives: 3710.0000 - false_positives: 1400.0000 - false_negatives: 677.0000
# Epoch 154/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6336 - true_positives: 4448.0000 - true_negatives: 3718.0000 - false_positives: 1392.0000 - false_negatives: 672.0000
# Epoch 155/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6331 - true_positives: 4454.0000 - true_negatives: 3725.0000 - false_positives: 1385.0000 - false_negatives: 666.0000
# Epoch 156/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6326 - true_positives: 4456.0000 - true_negatives: 3730.0000 - false_positives: 1380.0000 - false_negatives: 664.0000
# Epoch 157/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6322 - true_positives: 4459.0000 - true_negatives: 3734.0000 - false_positives: 1376.0000 - false_negatives: 661.0000
# Epoch 158/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6317 - true_positives: 4462.0000 - true_negatives: 3746.0000 - false_positives: 1364.0000 - false_negatives: 658.0000
# Epoch 159/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6313 - true_positives: 4462.0000 - true_negatives: 3753.0000 - false_positives: 1357.0000 - false_negatives: 658.0000
# Epoch 160/16000
# 1023/1023 [==============================] - 0s 5us/sample - loss: 0.6308 - true_positives: 4467.0000 - true_negatives: 3759.0000 - false_positives: 1351.0000 - false_negatives: 653.0000
# Epoch 161/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6303 - true_positives: 4469.0000 - true_negatives: 3763.0000 - false_positives: 1347.0000 - false_negatives: 651.0000
# Epoch 162/16000
# 1023/1023 [==============================] - 0s 5us/sample - loss: 0.6299 - true_positives: 4470.0000 - true_negatives: 3769.0000 - false_positives: 1341.0000 - false_negatives: 650.0000
# Epoch 163/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6294 - true_positives: 4473.0000 - true_negatives: 3773.0000 - false_positives: 1337.0000 - false_negatives: 647.0000
# Epoch 164/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6290 - true_positives: 4474.0000 - true_negatives: 3781.0000 - false_positives: 1329.0000 - false_negatives: 646.0000
# Epoch 165/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6285 - true_positives: 4477.0000 - true_negatives: 3789.0000 - false_positives: 1321.0000 - false_negatives: 643.0000
# Epoch 166/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6280 - true_positives: 4479.0000 - true_negatives: 3796.0000 - false_positives: 1314.0000 - false_negatives: 641.0000
# Epoch 167/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6276 - true_positives: 4481.0000 - true_negatives: 3801.0000 - false_positives: 1309.0000 - false_negatives: 639.0000
# Epoch 168/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6271 - true_positives: 4483.0000 - true_negatives: 3815.0000 - false_positives: 1295.0000 - false_negatives: 637.0000
# Epoch 169/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6266 - true_positives: 4484.0000 - true_negatives: 3816.0000 - false_positives: 1294.0000 - false_negatives: 636.0000
# Epoch 170/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6262 - true_positives: 4489.0000 - true_negatives: 3823.0000 - false_positives: 1287.0000 - false_negatives: 631.0000
# Epoch 171/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6257 - true_positives: 4492.0000 - true_negatives: 3836.0000 - false_positives: 1274.0000 - false_negatives: 628.0000
# Epoch 172/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6252 - true_positives: 4494.0000 - true_negatives: 3842.0000 - false_positives: 1268.0000 - false_negatives: 626.0000
# Epoch 173/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6248 - true_positives: 4498.0000 - true_negatives: 3848.0000 - false_positives: 1262.0000 - false_negatives: 622.0000
# Epoch 174/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6243 - true_positives: 4497.0000 - true_negatives: 3852.0000 - false_positives: 1258.0000 - false_negatives: 623.0000
# Epoch 175/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6238 - true_positives: 4500.0000 - true_negatives: 3860.0000 - false_positives: 1250.0000 - false_negatives: 620.0000
# Epoch 176/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6234 - true_positives: 4499.0000 - true_negatives: 3860.0000 - false_positives: 1250.0000 - false_negatives: 621.0000
# Epoch 177/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6229 - true_positives: 4501.0000 - true_negatives: 3863.0000 - false_positives: 1247.0000 - false_negatives: 619.0000
# Epoch 178/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6224 - true_positives: 4500.0000 - true_negatives: 3874.0000 - false_positives: 1236.0000 - false_negatives: 620.0000
# Epoch 179/16000
# 1023/1023 [==============================] - 0s 5us/sample - loss: 0.6220 - true_positives: 4501.0000 - true_negatives: 3880.0000 - false_positives: 1230.0000 - false_negatives: 619.0000
# Epoch 180/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6215 - true_positives: 4500.0000 - true_negatives: 3886.0000 - false_positives: 1224.0000 - false_negatives: 620.0000
# Epoch 181/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6210 - true_positives: 4499.0000 - true_negatives: 3892.0000 - false_positives: 1218.0000 - false_negatives: 621.0000
# Epoch 182/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6205 - true_positives: 4500.0000 - true_negatives: 3897.0000 - false_positives: 1213.0000 - false_negatives: 620.0000
# Epoch 183/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6201 - true_positives: 4501.0000 - true_negatives: 3903.0000 - false_positives: 1207.0000 - false_negatives: 619.0000
# Epoch 184/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6196 - true_positives: 4503.0000 - true_negatives: 3910.0000 - false_positives: 1200.0000 - false_negatives: 617.0000
# Epoch 185/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6191 - true_positives: 4508.0000 - true_negatives: 3915.0000 - false_positives: 1195.0000 - false_negatives: 612.0000
# Epoch 186/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6187 - true_positives: 4507.0000 - true_negatives: 3924.0000 - false_positives: 1186.0000 - false_negatives: 613.0000
# Epoch 187/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6182 - true_positives: 4507.0000 - true_negatives: 3927.0000 - false_positives: 1183.0000 - false_negatives: 613.0000
# Epoch 188/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6177 - true_positives: 4510.0000 - true_negatives: 3930.0000 - false_positives: 1180.0000 - false_negatives: 610.0000
# Epoch 189/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6172 - true_positives: 4509.0000 - true_negatives: 3933.0000 - false_positives: 1177.0000 - false_negatives: 611.0000
# Epoch 190/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6168 - true_positives: 4509.0000 - true_negatives: 3939.0000 - false_positives: 1171.0000 - false_negatives: 611.0000
# Epoch 191/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6163 - true_positives: 4509.0000 - true_negatives: 3943.0000 - false_positives: 1167.0000 - false_negatives: 611.0000
# Epoch 192/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6158 - true_positives: 4511.0000 - true_negatives: 3949.0000 - false_positives: 1161.0000 - false_negatives: 609.0000
# Epoch 193/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6153 - true_positives: 4515.0000 - true_negatives: 3959.0000 - false_positives: 1151.0000 - false_negatives: 605.0000
# Epoch 194/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6148 - true_positives: 4513.0000 - true_negatives: 3971.0000 - false_positives: 1139.0000 - false_negatives: 607.0000
# Epoch 195/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6144 - true_positives: 4518.0000 - true_negatives: 3973.0000 - false_positives: 1137.0000 - false_negatives: 602.0000
# Epoch 196/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6139 - true_positives: 4516.0000 - true_negatives: 3976.0000 - false_positives: 1134.0000 - false_negatives: 604.0000
# Epoch 197/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6134 - true_positives: 4521.0000 - true_negatives: 3980.0000 - false_positives: 1130.0000 - false_negatives: 599.0000
# Epoch 198/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6129 - true_positives: 4519.0000 - true_negatives: 3990.0000 - false_positives: 1120.0000 - false_negatives: 601.0000
# Epoch 199/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6125 - true_positives: 4522.0000 - true_negatives: 3995.0000 - false_positives: 1115.0000 - false_negatives: 598.0000
# Epoch 200/16000
# 1023/1023 [==============================] - 0s 8us/sample - loss: 0.6120 - true_positives: 4520.0000 - true_negatives: 4004.0000 - false_positives: 1106.0000 - false_negatives: 600.0000
# Epoch 201/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6115 - true_positives: 4518.0000 - true_negatives: 4008.0000 - false_positives: 1102.0000 - false_negatives: 602.0000
# Epoch 202/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6110 - true_positives: 4520.0000 - true_negatives: 4012.0000 - false_positives: 1098.0000 - false_negatives: 600.0000
# Epoch 203/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6105 - true_positives: 4518.0000 - true_negatives: 4019.0000 - false_positives: 1091.0000 - false_negatives: 602.0000
# Epoch 204/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6101 - true_positives: 4521.0000 - true_negatives: 4023.0000 - false_positives: 1087.0000 - false_negatives: 599.0000
# Epoch 205/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6096 - true_positives: 4520.0000 - true_negatives: 4024.0000 - false_positives: 1086.0000 - false_negatives: 600.0000
# Epoch 206/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6091 - true_positives: 4520.0000 - true_negatives: 4030.0000 - false_positives: 1080.0000 - false_negatives: 600.0000
# Epoch 207/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6086 - true_positives: 4523.0000 - true_negatives: 4032.0000 - false_positives: 1078.0000 - false_negatives: 597.0000
# Epoch 208/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6081 - true_positives: 4524.0000 - true_negatives: 4036.0000 - false_positives: 1074.0000 - false_negatives: 596.0000
# Epoch 209/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6076 - true_positives: 4523.0000 - true_negatives: 4039.0000 - false_positives: 1071.0000 - false_negatives: 597.0000
# Epoch 210/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6071 - true_positives: 4523.0000 - true_negatives: 4048.0000 - false_positives: 1062.0000 - false_negatives: 597.0000
# Epoch 211/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6067 - true_positives: 4529.0000 - true_negatives: 4052.0000 - false_positives: 1058.0000 - false_negatives: 591.0000
# Epoch 212/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6062 - true_positives: 4526.0000 - true_negatives: 4056.0000 - false_positives: 1054.0000 - false_negatives: 594.0000
# Epoch 213/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6057 - true_positives: 4527.0000 - true_negatives: 4059.0000 - false_positives: 1051.0000 - false_negatives: 593.0000
# Epoch 214/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6052 - true_positives: 4526.0000 - true_negatives: 4063.0000 - false_positives: 1047.0000 - false_negatives: 594.0000
# Epoch 215/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6047 - true_positives: 4529.0000 - true_negatives: 4072.0000 - false_positives: 1038.0000 - false_negatives: 591.0000
# Epoch 216/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6042 - true_positives: 4532.0000 - true_negatives: 4077.0000 - false_positives: 1033.0000 - false_negatives: 588.0000
# Epoch 217/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6037 - true_positives: 4531.0000 - true_negatives: 4081.0000 - false_positives: 1029.0000 - false_negatives: 589.0000
# Epoch 218/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6033 - true_positives: 4532.0000 - true_negatives: 4083.0000 - false_positives: 1027.0000 - false_negatives: 588.0000
# Epoch 219/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6028 - true_positives: 4525.0000 - true_negatives: 4086.0000 - false_positives: 1024.0000 - false_negatives: 595.0000
# Epoch 220/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6023 - true_positives: 4536.0000 - true_negatives: 4079.0000 - false_positives: 1031.0000 - false_negatives: 584.0000
# Epoch 221/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6018 - true_positives: 4518.0000 - true_negatives: 4098.0000 - false_positives: 1012.0000 - false_negatives: 602.0000
# Epoch 222/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.6013 - true_positives: 4544.0000 - true_negatives: 4078.0000 - false_positives: 1032.0000 - false_negatives: 576.0000
# Epoch 223/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.6008 - true_positives: 4520.0000 - true_negatives: 4104.0000 - false_positives: 1006.0000 - false_negatives: 600.0000
# Epoch 224/16000
# 1023/1023 [==============================] - 0s 5us/sample - loss: 0.6003 - true_positives: 4544.0000 - true_negatives: 4090.0000 - false_positives: 1020.0000 - false_negatives: 576.0000
# Epoch 225/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.5998 - true_positives: 4532.0000 - true_negatives: 4105.0000 - false_positives: 1005.0000 - false_negatives: 588.0000
# Epoch 226/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.5993 - true_positives: 4545.0000 - true_negatives: 4101.0000 - false_positives: 1009.0000 - false_negatives: 575.0000
# Epoch 227/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 0.5988 - true_positives: 4539.0000 - true_negatives: 4109.0000 - false_positives: 1001.0000 - false_negatives: 581.0000
# Epoch 228/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.5983 - true_positives: 4543.0000 - true_negatives: 4112.0000 - false_positives: 998.0000 - false_negatives: 577.0000
# Epoch 229/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.5979 - true_positives: 4542.0000 - true_negatives: 4119.0000 - false_positives: 991.0000 - false_negatives: 578.0000
# Epoch 230/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.5974 - true_positives: 4547.0000 - true_negatives: 4120.0000 - false_positives: 990.0000 - false_negatives: 573.0000
# Epoch 231/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.5969 - true_positives: 4545.0000 - true_negatives: 4136.0000 - false_positives: 974.0000 - false_negatives: 575.0000
# Epoch 232/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.5964 - true_positives: 4549.0000 - true_negatives: 4140.0000 - false_positives: 970.0000 - false_negatives: 571.0000
# Epoch 233/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.5959 - true_positives: 4544.0000 - true_negatives: 4149.0000 - false_positives: 961.0000 - false_negatives: 576.0000
# Epoch 234/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.5954 - true_positives: 4549.0000 - true_negatives: 4155.0000 - false_positives: 955.0000 - false_negatives: 571.0000
# Epoch 235/16000
# 1023/1023 [==============================] - 0s 5us/sample - loss: 0.5949 - true_positives: 4544.0000 - true_negatives: 4165.0000 - false_positives: 945.0000 - false_negatives: 576.0000
# Epoch 236/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 0.5944 - true_positives: 4553.0000 - true_negatives: 4160.0000 - false_positives: 950.0000 - false_negatives: 567.0000
# Epoch 237/16000
# ...
# Epoch 15926/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.9551e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15927/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.9501e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15928/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.9452e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15929/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.9403e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15930/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.9353e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15931/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.9304e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15932/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.9255e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15933/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.9206e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15934/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.9156e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15935/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.9107e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15936/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.9058e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15937/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.9009e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15938/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.8960e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15939/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.8911e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15940/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.8862e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15941/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.8814e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15942/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.8765e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15943/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.8716e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15944/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.8667e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15945/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.8618e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15946/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.8570e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15947/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.8521e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15948/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.8473e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15949/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.8424e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15950/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.8376e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15951/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.8327e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15952/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.8279e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15953/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.8230e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15954/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.8182e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15955/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.8134e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15956/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.8086e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15957/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.8037e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15958/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.7989e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15959/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.7941e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15960/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.7893e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15961/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.7845e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15962/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.7797e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15963/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.7749e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15964/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.7701e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15965/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.7653e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15966/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.7605e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15967/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.7557e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15968/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.7510e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15969/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.7462e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15970/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.7414e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15971/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.7367e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15972/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.7319e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15973/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.7271e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15974/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.7224e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15975/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.7176e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15976/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 8.7129e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15977/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 8.7082e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15978/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 8.7034e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15979/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 8.6987e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15980/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 8.6940e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15981/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.6892e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15982/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.6845e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15983/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 8.6798e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15984/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 8.6751e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15985/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 8.6704e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15986/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 8.6657e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15987/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 8.6610e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15988/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.6563e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15989/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 8.6516e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15990/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 8.6469e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15991/16000
# 1023/1023 [==============================] - 0s 6us/sample - loss: 8.6422e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15992/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 8.6375e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15993/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 8.6328e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15994/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 8.6282e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15995/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 8.6235e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15996/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 8.6188e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15997/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 8.6142e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15998/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 8.6095e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 15999/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 8.6048e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00
# Epoch 16000/16000
# 1023/1023 [==============================] - 0s 7us/sample - loss: 8.6002e-06 - true_positives: 5120.0000 - true_negatives: 5110.0000 - false_positives: 0.0000e+00 - false_negatives: 0.0000e+00

# %% [markdown]
# ### $\textbf{Plot LFSR State Observation & Network's Future State Predictions}$

# %%
# Plot true n'th vs. predicted (n + 1)'st'...
if plot_prediction_masks:
    
    # Plot LFSR state progression & predicted progression (in parallel)
    true_vs_predicted(idx0=0, idx1=50, input_obs=X,
                      output_activations=output_activations)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-3eb55cd98d0e> in <module>
#       3
#       4     # Plot LFSR state progression & predicted progression (in parallel)
# ----> 5     true_vs_predicted(idx0=0, idx1=50, input_obs=X,
#       6                       output_activations=output_activations)
#
# NameError: name 'true_vs_predicted' is not defined

# %% [markdown]
# ### $\textbf{Get Activations of Hidden & Output Layers}$

# %%
######################################
# Hidden sigmoidal layer activations #
######################################

# Gather hidden layer outputs from original model
h_layer = model.get_layer('hidden').output

# Separate model to spy on hidden layer activations
hidden_layer_model = Model(inputs=model.input,
    outputs=h_layer)

# Sigmoidal hidden layer outputs / activations
hidden_activations = hidden_layer_model.predict(X)

######################################
# Output sigmoidal layer activations #
######################################

# Get model output activations
output_activations = model.predict(X)

# %% [markdown]
# ### $\textbf{Visualize LFSR State and Feedforward Binary Network}$

# %%
##############################
# Visualization config panel #
##############################

config = {
    'figsize': (9.9, 7),
    'deg': deg,
    'x_mid': (deg - 1) / 2,
    'cmap': 'cividis',
    'y_input': 0,
    'y_hidden': 0.45,
    'y_output': 0.9,
    'y_decision': 1,
    'y_LFSR_loop': -0.1,
    'ylim': [-0.32, 1.2],
    'num_hidden': 2 * deg,
    'num_input': deg,
    'num_output': deg,
    'node_size': 10,
    'link_width': 1,
    'net_link_alpha': 0.6,
    'arrow_size': 8,
    'net_feedback_linestyle':'--'
}

lfsr_prediction_animation(
    lfsr=LFSRs[p], config=config, model=model,
    state_sequence=X, hidden_activations=hidden_activations,
    output_activations=output_activations,
    run_animation=True, interval=1000, blit=True, repeat=True)
